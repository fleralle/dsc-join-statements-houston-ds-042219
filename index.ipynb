# %% [markdown]
# # Join Statements

# %% [markdown]
# ## Introduction
#
# In this section, you will learn about several types of join statements.  Joins are the primary mechanism for combining data from multiple tables. In order to do this, you define the common attribute(s) between tables in order for them to be combined.
#
# ## Objectives
#
# You will be able to:
#
# * Compare and contrast the various types of joins
# * Discuss the syntax and structure of join statements
# * Discuss the role of foreign and primary keys in them
#
# ## CRM Schema
#
# In almost all industry cases, rather than just working with a single table you will generally need data from multiple tables. Doing this requires the use of **joins** using shared columns from the two tables. For example, here's a diagram of a mock customer relationship management database.
# <img src='images/Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
#
# As usual, you'll start by connecting to the database.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Displaying product details along with order details
# Let's say you need to generate some report that includes details about products from orders. To do that, we would need to take data from multiple tables in a single statement.

# %%
cur.execute("""select * from orderdetails
                        join products
                        on orderdetails.productCode = products.productCode
                        limit 10;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4
#
#   productCode                          productName   productLine productScale  \
# 0    S18_1749             1917 Grand Touring Sedan  Vintage Cars         1:18
# 1    S18_2248                   1911 Ford Town Car  Vintage Cars         1:18
# 2    S18_4409  1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars         1:18
# 3    S24_3969     1936 Mercedes Benz 500k Roadster  Vintage Cars         1:24
# 4    S18_2325            1932 Model A Ford J-Coupe  Vintage Cars         1:18
#
#                productVendor  \
# 0  Welly Diecast Productions
# 1    Motor City Art Classics
# 2              Exoto Designs
# 3          Red Start Diecast
# 4      Autoart Studio Design
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This 1:18 scale replica of the 1917 Grand Tour...            2724    86.70
# 1  Features opening hood, opening doors, opening ...             540    33.30
# 2  This 1:18 scale precision die cast replica fea...            6553    43.26
# 3  This model features grille-mounted chrome horn...            2081    21.75
# 4  This model features grille-mounted chrome horn...            9354    58.48
#
#      MSRP
# 0  170.00
# 1   60.54
# 2   92.03
# 3   41.03
# 4  127.13

# %% [markdown]
# ## Compared to the individual tables:

# %% [markdown]
# ### orderdetails

# %%
cur.execute("""select * from orderdetails limit 10;""")
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4

# %% [markdown]
# ### products

# %%
cur.execute("""select * from products limit 10;""")
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  Turnable front wheels; steering function; deta...            7305    98.58
# 2  Official Moto Guzzi logos and insignias, saddl...            6625    68.99
# 3  Model features, official Harley Davidson logos...            5582    91.02
# 4  Features include: Turnable front wheels; steer...            3252    85.68
#
#      MSRP
# 0   95.70
# 1  214.30
# 2  118.94
# 3  193.66
# 4  136.00

# %% [markdown]
# ## the using clause
# A more concise way to join the tables if the column name is identical is the using clause. Rather then saying on `tableA.column = tableB.column` we can simply say `using(column)`. Again, this only works if the column is identically named for both tables.

# %%
cur.execute("""select * from orderdetails
                        join products
                        using(productCode)
                        limit 10;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4
#
#                            productName   productLine productScale  \
# 0             1917 Grand Touring Sedan  Vintage Cars         1:18
# 1                   1911 Ford Town Car  Vintage Cars         1:18
# 2  1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars         1:18
# 3     1936 Mercedes Benz 500k Roadster  Vintage Cars         1:24
# 4            1932 Model A Ford J-Coupe  Vintage Cars         1:18
#
#                productVendor  \
# 0  Welly Diecast Productions
# 1    Motor City Art Classics
# 2              Exoto Designs
# 3          Red Start Diecast
# 4      Autoart Studio Design
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This 1:18 scale replica of the 1917 Grand Tour...            2724    86.70
# 1  Features opening hood, opening doors, opening ...             540    33.30
# 2  This 1:18 scale precision die cast replica fea...            6553    43.26
# 3  This model features grille-mounted chrome horn...            2081    21.75
# 4  This model features grille-mounted chrome horn...            9354    58.48
#
#      MSRP
# 0  170.00
# 1   60.54
# 2   92.03
# 3   41.03
# 4  127.13

# %% [markdown]
# ## Aliasing
# Alternatively, you can also alias tables by giving them an alternative shorthand name directly after them. Here we use the aliases 'o' and 'p' for orderdetails and products respectively.

# %%
cur.execute("""select * from orderdetails o
                        join products p
                        on o.productCode = p.productCode
                        limit 10;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4
#
#   productCode                          productName   productLine productScale  \
# 0    S18_1749             1917 Grand Touring Sedan  Vintage Cars         1:18
# 1    S18_2248                   1911 Ford Town Car  Vintage Cars         1:18
# 2    S18_4409  1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars         1:18
# 3    S24_3969     1936 Mercedes Benz 500k Roadster  Vintage Cars         1:24
# 4    S18_2325            1932 Model A Ford J-Coupe  Vintage Cars         1:18
#
#                productVendor  \
# 0  Welly Diecast Productions
# 1    Motor City Art Classics
# 2              Exoto Designs
# 3          Red Start Diecast
# 4      Autoart Studio Design
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This 1:18 scale replica of the 1917 Grand Tour...            2724    86.70
# 1  Features opening hood, opening doors, opening ...             540    33.30
# 2  This 1:18 scale precision die cast replica fea...            6553    43.26
# 3  This model features grille-mounted chrome horn...            2081    21.75
# 4  This model features grille-mounted chrome horn...            9354    58.48
#
#      MSRP
# 0  170.00
# 1   60.54
# 2   92.03
# 3   41.03
# 4  127.13

# %% [markdown]
# ## Left Joins
#
# By default, a join is an inner join, or the intersection between two tables. In other words, the join between orders and products is only for productCodes that are in both the orderdetails and products tables. If a product had yet to be ordered (and wasn't in the orderdetails table) then it would also not be in the result of the join.
#
# There are many other types of joins, displayed below. Of these, sqlite does not support outer joins, but it is good to be aware of as more powerful versions of sql such as PostgreSQL support these additional functions.
#
# <img src='images/venn.png' width="700">

# %% [markdown]
# For example, the statement
#
# `select * from products left join orderdetails; `
#
# would return all products, even those that hadn't been ordered.
# You can imagine that all products in inventory should have a description in the product table, but perhaps not every product is represented in the orderdetails table.

# %%
cur.execute("""select * from products
                        left join orderdetails
                        using(productCode);
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
print(len(df))
print(len(df[df.orderNumber.isnull()]))
df[df.orderNumber.isnull()].head()
# Out:
# 2997
# 1
#      productCode        productName   productLine productScale  \
# 1122    S18_3233  1985 Toyota Supra  Classic Cars         1:18
#
#                  productVendor  \
# 1122  Highway 66 Mini Classics
#
#                                      productDescription quantityInStock  \
# 1122  This model features soft rubber tires, working...            7733
#
#      buyPrice    MSRP orderNumber quantityOrdered priceEach orderLineNumber
# 1122    57.01  107.57        None            None      None            None

# %% [markdown]
# As you can see, its rare, but there is one product that has yet to be ordered

# %% [markdown]
# ## Primary Versus Foreign Keys
#
# Another important consideration when performing joins is to think more about the key or column you are joining on. As you'll see in upcoming lessons, this can lead to interesting behavior if the join value is not unique in one or both of the tables. In all of the above examples, you joined two tables using the **primary key**. The primary key(s) of a table are those column(s) which uniquely identify a row. You'll also see this designated in our schema diagram with the asterisk (*).
# <img src='images/Database-Schema.png' width=550>

# %% [markdown]
# You can also join tables using **foreign keys** which are not the primary key for that particular table, but rather another table. For example, employeeNumber is the primary key for the employees table and corresponds to the salesRepEmployeeNumber of the customers table. In the customers table, salesRepEmployeeNumber is only a foreign key, and is unlikely to be a unique identifier, as it is likely that an employee serves multiple customers. As such, in the resulting view, employeeNumber would no longer be a unique field.

# %%
cur.execute("""select * from customers c
                        join employees e
                        on c.salesRepEmployeeNumber = e.employeeNumber
                        order by employeeNumber;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head(50)
# Out:
#    customerNumber                       customerName contactLastName  \
# 0             124       Mini Gifts Distributors Ltd.          Nelson
# 1             129                    Mini Wheels Co.          Murphy
# 2             161               Technics Stores Inc.       Hashimoto
# 3             321           Corporate Gift Ideas Co.           Brown
# 4             450          The Sharp Gifts Warehouse           Frick
# 5             487           Signal Collectibles Ltd.          Taylor
# 6             112                 Signal Gift Stores            King
# 7             205                  Toys4GrownUps.com           Young
# 8             219                  Boards & Toys Co.           Young
# 9             239       Collectable Mini Designs Co.        Thompson
# 10            347         Men 'R' US Retailers, Ltd.        Chandler
# 11            475        West Coast Collectables Co.        Thompson
# 12            173         Cambridge Collectables Co.           Tseng
# 13            204           Online Mini Collectables         Barajas
# 14            320                Mini Creations Ltd.           Huang
# 15            339            Classic Gift Ideas, Inc       Cervantes
# 16            379         Collectables For Less Inc.          Nelson
# 17            495               Diecast Collectables          Franco
# 18            157              Diecast Classics Inc.           Leong
# 19            198            Auto-Moto Classics Inc.          Taylor
# 20            286               Marta's Replicas Co.       Hernandez
# 21            362                  Gifts4AllAges.com         Yoshido
# 22            363       Online Diecast Creations Co.           Young
# 23            462                   FunGiftIdeas.com         Benitez
# 24            151                 Muscle Machine Inc           Young
# 25            168             American Souvenirs Inc          Franco
# 26            181                    Vitachrome Inc.           Frick
# 27            233       Québec Home Shopping Network       Fresnière
# 28            424               Classic Legends Inc.       Hernandez
# 29            455                   Super Scale Inc.          Murphy
# 30            456                    Microscale Inc.            Choi
# 31            131                  Land of Toys Inc.             Lee
# 32            175                    Gift Depot Inc.            King
# 33            202     Canadian Gift Exchange Network          Tamuri
# 34            260  Royal Canadian Collectables, Ltd.         Lincoln
# 35            319                      Mini Classics           Frick
# 36            328            Tekni Collectables Inc.           Brown
# 37            447                   Gift Ideas Corp.           Lewis
# 38            486       Motor Mint Distributors Inc.         Salazar
# 39            146             Saveley & Henriot, Co.         Saveley
# 40            172          La Corne D'abondance, Co.        Bertrand
# 41            250                    Lyon Souveniers        Da Silva
# 42            350               Marseille Mini Autos         Lebihan
# 43            353                 Reims Collectables         Henriot
# 44            406                  Auto Canal+ Petit         Perrier
# 45            103                  Atelier graphique         Schmitt
# 46            119                  La Rochelle Gifts         Labrune
# 47            141             Euro+ Shopping Channel          Freyre
# 48            171           Daedalus Designs Imports           Rancé
# 49            209                        Mini Caravy         Citeaux
#
#    contactFirstName             phone                   addressLine1  \
# 0             Susan        4155551450                5677 Strong St.
# 1             Julie        6505555787      5557 North Pendale Street
# 2              Juri        6505556809              9408 Furth Circle
# 3             Julie        6505551386                7734 Strong St.
# 4               Sue        4085553659                 3086 Ingle Ln.
# 5               Sue        4155554312              2793 Furth Circle
# 6              Jean        7025551838                8489 Strong St.
# 7             Julie        6265557265             78934 Hillside Dr.
# 8              Mary        3105552373               4097 Douglas Av.
# 9           Valarie        7605558146               361 Furth Circle
# 10            Brian        2155554369               6047 Douglas Av.
# 11            Steve        3105553722              3675 Furth Circle
# 12            Jerry        6175555555                 4658 Baden Av.
# 13           Miguel        6175557555             7635 Spinnaker Dr.
# 14             Wing        5085559555              4575 Hillside Dr.
# 15        Francisca        2155554695               782 First Street
# 16            Allen        6175558555               7825 Douglas Av.
# 17          Valarie        6175552555                 6251 Ingle Ln.
# 18           Kelvin        2155551555               7586 Pompton St.
# 19           Leslie        6175558428              16780 Pompton St.
# 20            Marta        6175558555            39323 Spinnaker Dr.
# 21             Juri        6175559555             8616 Spinnaker Dr.
# 22          Dorothy        6035558647       2304 Long Airport Avenue
# 23          Violeta        5085552555              1785 First Street
# 24             Jeff        2125557413              4092 Furth Circle
# 25            Keith        2035557845              149 Spinnaker Dr.
# 26          Michael        2125551500              2678 Kingston Rd.
# 27            Jean     (514) 555-8054             43 rue St. Laurent
# 28            Maria        2125558493               5905 Pompton St.
# 29           Leslie        2035559545       567 North Pendale Street
# 30               Yu        2125551957      5290 North Pendale Street
# 31             Kwai        2125557818        897 Long Airport Avenue
# 32            Julie        2035552570            25593 South Bay Ln.
# 33           Yoshi     (604) 555-3392                   1900 Oak St.
# 34       Elizabeth     (604) 555-4555             23 Tsawassen Blvd.
# 35            Steve        9145554562      3758 North Pendale Street
# 36          William        2015559350                  7476 Moss Rd.
# 37              Dan        2035554407               2440 Pompton St.
# 38             Rosa        2155559857              11328 Douglas Av.
# 39            Mary         78.32.5555             2, rue du Commerce
# 40            Marie    (1) 42.34.2555        265, boulevard Charonne
# 41           Daniel  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 42        Laurence         91.24.4555           12, rue des Bouchers
# 43            Paul         26.47.1555             59 rue de l'Abbaye
# 44        Dominique    (1) 47.55.6555              25, rue Lauriston
# 45          Carine         40.32.2555                 54, rue Royale
# 46          Janine         40.67.8555   67, rue des Cinquante Otages
# 47           Diego     (91) 555 94 44             C/ Moralzarzal, 86
# 48         Martine         20.16.1555       184, chaussée de Tournai
# 49      Frédérique         88.60.1555               24, place Kléber
#
#    addressLine2           city   state postalCode    ...      \
# 0                   San Rafael      CA      97562    ...
# 1                San Francisco      CA      94217    ...
# 2                   Burlingame      CA      94217    ...
# 3                San Francisco      CA      94217    ...
# 4                     San Jose      CA      94217    ...
# 5                     Brisbane      CA      94217    ...
# 6                    Las Vegas      NV      83030    ...
# 7                     Pasadena      CA      90003    ...
# 8                     Glendale      CA      92561    ...
# 9                    San Diego      CA      91217    ...
# 10                 Los Angeles      CA      91003    ...
# 11                     Burbank      CA      94019    ...
# 12                   Cambridge      MA      51247    ...
# 13                  Brickhaven      MA      58339    ...
# 14                 New Bedford      MA      50553    ...
# 15                Philadelphia      PA      71270    ...
# 16                  Brickhaven      MA      58339    ...
# 17                      Boston      MA      51003    ...
# 18                   Allentown      PA      70267    ...
# 19                  Brickhaven      MA      58339    ...
# 20                   Cambridge      MA      51247    ...
# 21                      Boston      MA      51003    ...
# 22                      Nashua      NH      62005    ...
# 23                 New Bedford      MA      50553    ...
# 24    Suite 400            NYC      NY      10022    ...
# 25    Suite 101      New Haven      CT      97823    ...
# 26    Suite 101            NYC      NY      10022    ...
# 27                    Montréal  Québec    H1J 1C3    ...
# 28    Suite 750            NYC      NY      10022    ...
# 29                   New Haven      CT      97823    ...
# 30    Suite 200            NYC      NY      10022    ...
# 31                         NYC      NY      10022    ...
# 32                 Bridgewater      CT      97562    ...
# 33                   Vancouver      BC    V3F 2K1    ...
# 34                   Tsawassen      BC    T2F 8M4    ...
# 35                White Plains      NY      24067    ...
# 36                      Newark      NJ      94019    ...
# 37                    Glendale      CT      97561    ...
# 38                Philadelphia      PA      71270    ...
# 39                        Lyon              69004    ...
# 40                       Paris              75012    ...
# 41                       Paris              75508    ...
# 42                   Marseille              13008    ...
# 43                       Reims              51100    ...
# 44                       Paris              75016    ...
# 45                      Nantes              44000    ...
# 46                      Nantes              44000    ...
# 47                      Madrid              28034    ...
# 48                       Lille              59000    ...
# 49                  Strasbourg              67000    ...
#
#    salesRepEmployeeNumber creditLimit employeeNumber   lastName firstName  \
# 0                    1165   210500.00           1165   Jennings    Leslie
# 1                    1165    64600.00           1165   Jennings    Leslie
# 2                    1165    84600.00           1165   Jennings    Leslie
# 3                    1165   105000.00           1165   Jennings    Leslie
# 4                    1165    77600.00           1165   Jennings    Leslie
# 5                    1165    60300.00           1165   Jennings    Leslie
# 6                    1166    71800.00           1166   Thompson    Leslie
# 7                    1166    90700.00           1166   Thompson    Leslie
# 8                    1166    11000.00           1166   Thompson    Leslie
# 9                    1166   105000.00           1166   Thompson    Leslie
# 10                   1166    57700.00           1166   Thompson    Leslie
# 11                   1166    55400.00           1166   Thompson    Leslie
# 12                   1188    43400.00           1188   Firrelli     Julie
# 13                   1188    68700.00           1188   Firrelli     Julie
# 14                   1188    94500.00           1188   Firrelli     Julie
# 15                   1188    81100.00           1188   Firrelli     Julie
# 16                   1188    70700.00           1188   Firrelli     Julie
# 17                   1188    85100.00           1188   Firrelli     Julie
# 18                   1216   100600.00           1216  Patterson     Steve
# 19                   1216    23000.00           1216  Patterson     Steve
# 20                   1216   123700.00           1216  Patterson     Steve
# 21                   1216    41900.00           1216  Patterson     Steve
# 22                   1216   114200.00           1216  Patterson     Steve
# 23                   1216    85800.00           1216  Patterson     Steve
# 24                   1286   138500.00           1286      Tseng  Foon Yue
# 25                   1286        0.00           1286      Tseng  Foon Yue
# 26                   1286    76400.00           1286      Tseng  Foon Yue
# 27                   1286    48700.00           1286      Tseng  Foon Yue
# 28                   1286    67500.00           1286      Tseng  Foon Yue
# 29                   1286    95400.00           1286      Tseng  Foon Yue
# 30                   1286    39800.00           1286      Tseng  Foon Yue
# 31                   1323   114900.00           1323     Vanauf    George
# 32                   1323    84300.00           1323     Vanauf    George
# 33                   1323    90300.00           1323     Vanauf    George
# 34                   1323    89600.00           1323     Vanauf    George
# 35                   1323   102700.00           1323     Vanauf    George
# 36                   1323    43000.00           1323     Vanauf    George
# 37                   1323    49700.00           1323     Vanauf    George
# 38                   1323    72600.00           1323     Vanauf    George
# 39                   1337   123900.00           1337     Bondur      Loui
# 40                   1337    84300.00           1337     Bondur      Loui
# 41                   1337    68100.00           1337     Bondur      Loui
# 42                   1337    65000.00           1337     Bondur      Loui
# 43                   1337    81100.00           1337     Bondur      Loui
# 44                   1337    95000.00           1337     Bondur      Loui
# 45                   1370    21000.00           1370  Hernandez    Gerard
# 46                   1370   118200.00           1370  Hernandez    Gerard
# 47                   1370   227600.00           1370  Hernandez    Gerard
# 48                   1370    82900.00           1370  Hernandez    Gerard
# 49                   1370    53800.00           1370  Hernandez    Gerard
#
#    extension                            email officeCode reportsTo   jobTitle
# 0      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 1      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 2      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 3      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 4      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 5      x3291   ljennings@classicmodelcars.com          1      1143  Sales Rep
# 6      x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 7      x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 8      x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 9      x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 10     x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 11     x4065   lthompson@classicmodelcars.com          1      1143  Sales Rep
# 12     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 13     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 14     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 15     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 16     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 17     x2173   jfirrelli@classicmodelcars.com          2      1143  Sales Rep
# 18     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 19     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 20     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 21     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 22     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 23     x4334  spatterson@classicmodelcars.com          2      1143  Sales Rep
# 24     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 25     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 26     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 27     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 28     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 29     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 30     x2248      ftseng@classicmodelcars.com          3      1143  Sales Rep
# 31     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 32     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 33     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 34     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 35     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 36     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 37     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 38     x4102     gvanauf@classicmodelcars.com          3      1143  Sales Rep
# 39     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 40     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 41     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 42     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 43     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 44     x6493     lbondur@classicmodelcars.com          4      1102  Sales Rep
# 45     x2028   ghernande@classicmodelcars.com          4      1102  Sales Rep
# 46     x2028   ghernande@classicmodelcars.com          4      1102  Sales Rep
# 47     x2028   ghernande@classicmodelcars.com          4      1102  Sales Rep
# 48     x2028   ghernande@classicmodelcars.com          4      1102  Sales Rep
# 49     x2028   ghernande@classicmodelcars.com          4      1102  Sales Rep
#
# [50 rows x 21 columns]

# %% [markdown]
# Notice that this also returned both columns: salesRepEmployeeNumber and employeeNumber.

# %% [markdown]
# ## Summary
#
# In this lesson you investigated joins including the on and using clause, aliasing table names, left joins and primary and foreign keys.
